# %% [markdown]
# ## Task 1

# %% [markdown]
# Exploração dos endpoints da API. Utilizando o `site_id` MLB para Brasil.

# %%
import requests

# %%
# Simple search
hits = 5
query = "chromecast"
url = f"https://api.mercadolibre.com/sites/MLB/search?q={query}&limit={hits}#json"
response = requests.get(url)
search_result = response.json()

# %%
search_result
# Out:
# {'site_id': 'MLB',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'chromecast',
#  'paging': {'total': 702, 'primary_results': 702, 'offset': 0, 'limit': 5},
#  'results': [{'id': 'MLB5031637494',
#    'title': 'Smart Box Tv Intelbras Izy Play 2da Geração Android Quadcore Full Hd Usb Cor Preto Tipo De Controle Remoto De Voz',
#    'condition': 'new',
#    'thumbnail_id': '907774-MLU69599655432_052023',
#    'catalog_product_id': 'MLB23436737',
#    'listing_type_id': 'gold_pro',
#    'sanitized_title': 'smart-box-tv-intelbras-izy-play-2da-geraco-android-quadcore-full-hd-usb-cor-preto-tipo-de-controle-remoto-de-voz',
#    'permalink': 'https://www.mercadolivre.com.br/smart-box-tv-intelbras-izy-play-2da-geraco-android-quadcore-full-hd-usb-cor-preto-tipo-de-controle-remoto-de-voz/p/MLB23436737#wid=MLB5031637494&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLB',
#    'category_id': 'MLB133950',
#    'domain_id': 'MLB-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_907774-MLU69599655432_052023-I.jpg',
#    'currency_id': 'BRL',
#    'order_backend': 1,
#    'price': 289,
#    'original_price': 359,
#    'sale_price': {'price_id': '',
#     'amount': 289,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-11-20T03:01:00Z',
#      'end_time': '2024-12-01T01:59:00Z'},
#     'currency_id': 'BRL',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 359,
#     'type': 'promotion',
#     'metadata': {'campaign_discount_percentage': 19.5,
#      'campaign_end_date': '2024-12-01T01:59:00Z',
#      'campaign_id': 'P-MLB14359038',
#      'discount_meli_amount': 11.56,
#      'funding_mode': 'sale_fee',
#      'order_item_price': 289,
#      'promotion_id': 'OFFER-MLB5031637494-11091576296',
#      'promotion_type': 'marketplace_campaign'}},
#    'available_quantity': 500,
#    'official_store_id': 56642,
#    'official_store_name': 'Eshop',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-10-21T15:03:28.467Z',
#    'seller': {'id': 663212996, 'nickname': 'ESHOP_SP'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-23',
#     'city_name': 'Ribeirão Preto'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '19379357',
#      'value_name': 'TV Box Izy Play',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '19379357',
#        'name': 'TV Box Izy Play',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '10366',
#      'value_name': 'Intelbras',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '10366',
#        'name': 'Intelbras',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Cor',
#      'value_id': '52049',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Preto', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de produto',
#      'value_id': None,
#      'value_name': '7899298660910',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7899298660910',
#        'struct': None,
#        'source': 7571550481372610}],
#      'source': 7571550481372610,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Comprimento',
#      'value_id': '7827841',
#      'value_name': '100 mm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 100, 'unit': 'mm'},
#      'values': [{'id': '7827841',
#        'name': '100 mm',
#        'struct': {'number': 100, 'unit': 'mm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '19379358',
#      'value_name': 'Smart Box',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '19379358',
#        'name': 'Smart Box',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Cor principal',
#      'value_id': '2450295',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Preto',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8794133',
#      'value_name': 'IZY Play',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '8794133',
#        'name': 'IZY Play',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Comprimento da embalagem',
#      'value_id': None,
#      'value_name': '17 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 17, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '17 cm',
#        'struct': {'number': 17, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso da embalagem',
#      'value_id': None,
#      'value_name': '560 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 560, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '560 g',
#        'struct': {'number': 560, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '15329851',
#      'value_name': '380 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 380, 'unit': 'g'},
#      'values': [{'id': '15329851',
#        'name': '380 g',
#        'struct': {'number': 380, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 9,
#     'amount': 32.11,
#     'rate': 0,
#     'currency_id': 'BRL',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'decorations': None,
#    'promotions': [],
#    'inventory_id': 'NRYJ35651'},
#   {'id': 'MLB5122270756',
#    'title': 'Tv Stick Smart Tv Android 4k Wi-fi Hdmi Streaming Cor Preto Tipo De Controle Remoto Mini',
#    'condition': 'new',
#    'thumbnail_id': '777552-MLA80316430331_102024',
#    'catalog_product_id': 'MLB33388968',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'tv-stick-smart-tv-android-4k-wi-fi-hdmi-streaming-cor-preto-tipo-de-controle-remoto-mini',
#    'permalink': 'https://www.mercadolivre.com.br/tv-stick-smart-tv-android-4k-wi-fi-hdmi-streaming-cor-preto-tipo-de-controle-remoto-mini/p/MLB33388968#wid=MLB5122270756&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLB',
#    'category_id': 'MLB133950',
#    'domain_id': 'MLB-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_777552-MLA80316430331_102024-I.jpg',
#    'currency_id': 'BRL',
#    'order_backend': 2,
#    'price': 166,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 166,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'BRL',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-10-11T04:00:00.000Z',
#    'seller': {'id': 72364867, 'nickname': 'LSFARIASVARIEDADES'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '13838716',
#      'value_name': '4K',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '13838716', 'name': '4K', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '33429667',
#      'value_name': 'Transpeed',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '33429667',
#        'name': 'Transpeed',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Cor',
#      'value_id': '52049',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Preto', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de produto',
#      'value_id': None,
#      'value_name': '7901867765800',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7901867765800',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Comprimento',
#      'value_id': '9271706',
#      'value_name': '108 mm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 108, 'unit': 'mm'},
#      'values': [{'id': '9271706',
#        'name': '108 mm',
#        'struct': {'number': 108, 'unit': 'mm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Cor principal',
#      'value_id': '2450295',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Preto',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '10627416',
#      'value_name': 'Smart TV Box',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '10627416',
#        'name': 'Smart TV Box',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'}],
#    'installments': {'quantity': 12,
#     'amount': 16.14,
#     'rate': 16.64,
#     'currency_id': 'BRL',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'decorations': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLB3878402495',
#    'title': 'Mi Tv Stick 2ª Geração Xiaomi Controle De Voz Full Hd 8gb 1gb Ram Cor Preto',
#    'condition': 'new',
#    'thumbnail_id': '728741-MLA43334408824_092020',
#    'catalog_product_id': 'MLB15984003',
#    'listing_type_id': 'gold_pro',
#    'sanitized_title': 'mi-tv-stick-2-geraco-xiaomi-controle-de-voz-full-hd-8gb-1gb-ram-cor-preto',
#    'permalink': 'https://www.mercadolivre.com.br/mi-tv-stick-2-geraco-xiaomi-controle-de-voz-full-hd-8gb-1gb-ram-cor-preto/p/MLB15984003#wid=MLB3878402495&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLB',
#    'category_id': 'MLB133950',
#    'domain_id': 'MLB-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_728741-MLA43334408824_092020-I.jpg',
#    'currency_id': 'BRL',
#    'order_backend': 3,
#    'price': 291,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 291,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'BRL',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-10-10T04:00:00.000Z',
#    'seller': {'id': 414290428, 'nickname': 'OLDA5511456'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-78',
#     'city_name': 'Presidente Prudente'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '8863908',
#      'value_name': 'MDZ-24-AA',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '8863908',
#        'name': 'MDZ-24-AA',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '59387',
#      'value_name': 'Xiaomi',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '59387',
#        'name': 'Xiaomi',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Cor',
#      'value_id': '52049',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Preto', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de produto',
#      'value_id': None,
#      'value_name': '6971408152254',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '6971408152254',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Comprimento',
#      'value_id': '7818553',
#      'value_name': '8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 8, 'unit': 'cm'},
#      'values': [{'id': '7818553',
#        'name': '8 cm',
#        'struct': {'number': 8, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '196',
#      'value_name': 'Smart',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '196', 'name': 'Smart', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Cor principal',
#      'value_id': '2450295',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Preto',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '8840953',
#      'value_name': 'Mi TV Stick',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '8840953',
#        'name': 'Mi TV Stick',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '18841047',
#      'value_name': '202 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 202, 'unit': 'g'},
#      'values': [{'id': '18841047',
#        'name': '202 g',
#        'struct': {'number': 202, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 9,
#     'amount': 32.33,
#     'rate': 0,
#     'currency_id': 'BRL',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'decorations': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLB3670711256',
#    'title': 'Xiaomi Mi Box S Mdz-22-ab 1ª Geração 4k 8gb Preto 2gb Ram Com Comando De Voz',
#    'condition': 'new',
#    'thumbnail_id': '825424-MLU69953473320_062023',
#    'catalog_product_id': 'MLB13877783',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'xiaomi-mi-box-s-mdz-22-ab-1-geraco-4k-8gb-preto-2gb-ram-com-comando-de-voz',
#    'permalink': 'https://www.mercadolivre.com.br/xiaomi-mi-box-s-mdz-22-ab-1-geraco-4k-8gb-preto-2gb-ram-com-comando-de-voz/p/MLB13877783#wid=MLB3670711256&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLB',
#    'category_id': 'MLB133950',
#    'domain_id': 'MLB-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_825424-MLU69953473320_062023-I.jpg',
#    'currency_id': 'BRL',
#    'order_backend': 4,
#    'price': 389.7,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 389.7,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'BRL',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-05-21T04:00:00.000Z',
#    'seller': {'id': 1365270857, 'nickname': 'SELF ATACADO'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '9776696',
#      'value_name': 'MDZ-22-AB',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '9776696',
#        'name': 'MDZ-22-AB',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '59387',
#      'value_name': 'Xiaomi',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '59387',
#        'name': 'Xiaomi',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Cor',
#      'value_id': '52049',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Preto', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de produto',
#      'value_id': None,
#      'value_name': '6971408157044',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '6971408157044',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Comprimento',
#      'value_id': '10258566',
#      'value_name': '3.75 ',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 3.75, 'unit': '"'},
#      'values': [{'id': '10258566',
#        'name': '3.75 "',
#        'struct': {'number': 3.75, 'unit': '"'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Cor principal',
#      'value_id': '2450295',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Preto',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '6285420',
#      'value_name': 'Mi Box S',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '6285420',
#        'name': 'Mi Box S',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '5991223',
#      'value_name': '1 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 1, 'unit': 'kg'},
#      'values': [{'id': '5991223',
#        'name': '1 kg',
#        'struct': {'number': 1, 'unit': 'kg'},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 12,
#     'amount': 37.78,
#     'rate': 16.34,
#     'currency_id': 'BRL',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'decorations': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLB3853779333',
#    'title': 'Smart Tv Android Stick Full Hd Century Cor Preto Tipo De Controle Remoto Padrão',
#    'condition': 'new',
#    'thumbnail_id': '663952-MLU79105682430_092024',
#    'catalog_product_id': 'MLB40923284',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'smart-tv-android-stick-full-hd-century-cor-preto-tipo-de-controle-remoto-padro',
#    'permalink': 'https://www.mercadolivre.com.br/smart-tv-android-stick-full-hd-century-cor-preto-tipo-de-controle-remoto-padro/p/MLB40923284#wid=MLB3853779333&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLB',
#    'category_id': 'MLB133950',
#    'domain_id': 'MLB-STREAMING_MEDIA_DEVICES',
#    'thumbnail': 'http://http2.mlstatic.com/D_663952-MLU79105682430_092024-I.jpg',
#    'currency_id': 'BRL',
#    'order_backend': 5,
#    'price': 239.99,
#    'original_price': 399.99,
#    'sale_price': {'price_id': '',
#     'amount': 239.99,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-11-01T03:02:00Z',
#      'end_time': '2024-12-07T02:50:00Z'},
#     'currency_id': 'BRL',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 399.99,
#     'type': 'promotion',
#     'metadata': {'campaign_discount_percentage': 40,
#      'campaign_end_date': '2024-12-07T02:50:00Z',
#      'campaign_id': 'P-MLB14349290',
#      'discount_meli_amount': 14.4,
#      'funding_mode': 'sale_fee',
#      'order_item_price': 239.99,
#      'promotion_id': 'OFFER-MLB3853779333-11095433617',
#      'promotion_type': 'marketplace_campaign'}},
#    'available_quantity': 1,
#    'official_store_id': 1869,
#    'official_store_name': 'We Market',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'self_service_out',
#      'mandatory_free_shipping',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-11-01T20:28:54.793Z',
#    'seller': {'id': 1165626720, 'nickname': 'WEMG_'},
#    'address': {'state_id': 'BR-MG',
#     'state_name': 'Minas Gerais',
#     'city_id': 'TUxCQ0VYVDdjZTBi',
#     'city_name': 'Extrema'},
#    'attributes': [{'id': 'ALPHANUMERIC_MODEL',
#      'name': 'Modelo alfanumérico',
#      'value_id': '42757127',
#      'value_name': 'CT-ATV01',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '42757127',
#        'name': 'CT-ATV01',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '350226',
#      'value_name': 'Century',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '350226',
#        'name': 'Century',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Cor',
#      'value_id': '52049',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Preto', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de produto',
#      'value_id': None,
#      'value_name': '7898931486429',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7898931486429',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 4333789534002961,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '4834866',
#      'value_name': 'Smart Stick',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '4834866',
#        'name': 'Smart Stick',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Cor principal',
#      'value_id': '2450295',
#      'value_name': 'Preto',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Preto',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '19063947',
#      'value_name': 'AndroidTV',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': None,
#      'values': [{'id': '19063947',
#        'name': 'AndroidTV',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Comprimento da embalagem',
#      'value_id': None,
#      'value_name': '17.7 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 17.7, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '17.7 cm',
#        'struct': {'number': 17.7, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso da embalagem',
#      'value_id': None,
#      'value_name': '220 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_struct': {'number': 220, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '220 g',
#        'struct': {'number': 220, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 12,
#     'amount': 23.33,
#     'rate': 16.64,
#     'currency_id': 'BRL',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'decorations': None,
#    'promotions': [],
#    'inventory_id': 'MYXX12329'}],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB133950',
#      'name': 'Media Streaming',
#      'path_from_root': [{'id': 'MLB1000',
#        'name': 'Eletrônicos, Áudio e Vídeo'},
#       {'id': 'MLB133950', 'name': 'Media Streaming'}]}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as lojas oficiais', 'results': 25},
#     {'id': '56642', 'name': 'Eshop', 'results': 5},
#     {'id': '51368', 'name': 'JLS Eletronicos', 'results': 2},
#     {'id': '1869', 'name': 'We Market', 'results': 1}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'number',
#    'values': [{'id': '5-100', 'name': 'Mais de 5% OFF', 'results': 75},
#     {'id': '10-100', 'name': 'Mais de 10% OFF', 'results': 45},
#     {'id': '15-100', 'name': 'Mais de 15% OFF', 'results': 20},
#     {'id': '20-100', 'name': 'Mais de 20% OFF', 'results': 9},
#     {'id': '25-100', 'name': 'Mais de 25% OFF', 'results': 5},
#     {'id': '40-100', 'name': 'Mais de 40% OFF', 'results': 1}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-350.0', 'name': 'Até R$ 350', 'results': 198},
#     {'id': '350.0-400.0', 'name': 'R$350 a R$400', 'results': 124},
#     {'id': '400.0-*', 'name': 'Mais de R$400', 'results': 380}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com Mercado Pago', 'results': 702}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'Parcelamento sem juros', 'results': 702},
#     {'id': 'no_interest', 'name': 'Sem juros', 'results': 298}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 702},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 25}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 235}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 2}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 702}]},
#   {'id': 'all_payment_methods_discount',
#    'name': 'Descuentos para todos los medios de pago',
#    'type': 'number',
#    'values': [{'id': '10-100', 'name': 'Mais de 10% OFF', 'results': 14},
#     {'id': '15-100', 'name': 'Mais de 15% OFF', 'results': 11},
#     {'id': '20-100', 'name': 'Mais de 20% OFF', 'results': 6},
#     {'id': '25-100', 'name': 'Mais de 25% OFF', 'results': 3},
#     {'id': '30-100', 'name': 'Mais de 30% OFF', 'results': 1}]},
#   {'id': 'price_campaign_id',
#    'name': 'Campanha',
#    'type': 'number',
#    'values': [{'id': 'MLB34608', 'name': 'MLB34608', 'results': 6},
#     {'id': 'P-MLB14349290', 'name': 'P-MLB14349290', 'results': 6},
#     {'id': 'P-MLB14359038', 'name': 'P-MLB14359038', 'results': 2},
#     {'id': 'P-MLB14319108', 'name': 'P-MLB14319108', 'results': 1}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Grátis', 'results': 660}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '59387', 'name': 'Xiaomi', 'results': 283},
#     {'id': '52701', 'name': 'Google', 'results': 223},
#     {'id': '10366', 'name': 'Intelbras', 'results': 58},
#     {'id': '14329329', 'name': 'Mi', 'results': 37},
#     {'id': '350226', 'name': 'Century', 'results': 8},
#     {'id': '276243', 'name': 'Genérica', 'results': 5},
#     {'id': '45099', 'name': 'Aquário', 'results': 3},
#     {'id': '4812724', 'name': 'MiraScreen', 'results': 2},
#     {'id': '45918', 'name': 'Elsys', 'results': 2},
#     {'id': '33429667', 'name': 'Transpeed', 'results': 2},
#     {'id': '17208015', 'name': 'Chromecast', 'results': 2},
#     {'id': '11546966', 'name': 'Onn.', 'results': 2},
#     {'id': '9701064', 'name': 'BR', 'results': 1},
#     {'id': '7984', 'name': 'Mirage', 'results': 1},
#     {'id': '7294334', 'name': 'Asus', 'results': 1},
#     {'id': '2908708', 'name': 'Solo', 'results': 1},
#     {'id': '2804265', 'name': 'SM', 'results': 1},
#     {'id': '17418', 'name': 'Nvidia', 'results': 1}]},
#   {'id': 'DEVICE_FORMAT',
#    'name': 'Formato do dispositivo',
#    'type': 'STRING',
#    'values': [{'id': '8616496', 'name': 'Stick', 'results': 316},
#     {'id': '8616495', 'name': 'TV Box', 'results': 210},
#     {'id': '9234856', 'name': 'Pendant Box', 'results': 161}]},
#   {'id': 'INCLUDES_CELL_BATTERIES',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Inclui pilhas', 'results': 178}]},
#   {'id': 'INCLUDES_HDMI_CABLE',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Inclui cabo HDMI', 'results': 528}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Novo', 'results': 650},
#     {'id': '2230581', 'name': 'Usado', 'results': 51},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 1}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Cor principal',
#    'type': 'list',
#    'values': [{'id': '2450295', 'name': 'Preto', 'results': 365},
#     {'id': '2450308', 'name': 'Branco', 'results': 131},
#     {'id': '2450278', 'name': 'Azul-celeste', 'results': 5},
#     {'id': '2450294', 'name': 'Cinza', 'results': 1},
#     {'id': '2450293', 'name': 'Azul', 'results': 1}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '8840953', 'name': 'Mi TV Stick', 'results': 142},
#     {'id': '11281877', 'name': 'Chromecast', 'results': 84},
#     {'id': '9169579', 'name': 'Chromecast with Google TV', 'results': 44},
#     {'id': '6285420', 'name': 'Mi Box S', 'results': 44},
#     {'id': '8794133', 'name': 'IZY Play', 'results': 40},
#     {'id': '49506', 'name': '3', 'results': 12},
#     {'id': '40464', 'name': 'HD', 'results': 9},
#     {'id': '402606', 'name': 'Chromecast Ultra', 'results': 7},
#     {'id': '346619', 'name': 'Mi Box', 'results': 7},
#     {'id': '44144724', 'name': 'Mi Stick 4k', 'results': 3},
#     {'id': '14200507', 'name': 'Others', 'results': 3},
#     {'id': '11282071', 'name': 'Fire TV', 'results': 3},
#     {'id': '8850009', 'name': 'Streaming Box', 'results': 2},
#     {'id': '429982', 'name': '4K', 'results': 2},
#     {'id': '8958009', 'name': 'Mi Box 3', 'results': 1},
#     {'id': '8919739', 'name': 'Shield TV Pro Versión 2019', 'results': 1},
#     {'id': '8869529', 'name': 'TV Box', 'results': 1},
#     {'id': '6616542', 'name': 'Fire TV Stick 4K', 'results': 1},
#     {'id': '4806393', 'name': 'M2 Plus', 'results': 1},
#     {'id': '44154692', 'name': 'Fire Stick TV', 'results': 1},
#     {'id': '35536', 'name': 'G2', 'results': 1},
#     {'id': '333318', 'name': 'Nexus Player', 'results': 1},
#     {'id': '2345724', 'name': 'Stick', 'results': 1},
#     {'id': '14267338', 'name': 'Smart TV', 'results': 1},
#     {'id': '11616397', 'name': 'UHD Streaming Device', 'results': 1},
#     {'id': '11158915', 'name': 'Fire TV Stick', 'results': 1},
#     {'id': '10627416', 'name': 'Smart TV Box', 'results': 1}]},
#   {'id': 'OPERATING_SYSTEM',
#    'name': 'Sistema operacional',
#    'type': 'STRING',
#    'values': [{'id': '7601503', 'name': 'Android TV', 'results': 186},
#     {'id': '8794132', 'name': 'Android TV 9.0', 'results': 164},
#     {'id': '355776', 'name': 'Chrome OS', 'results': 81},
#     {'id': '12103848', 'name': 'Android TV 11', 'results': 65},
#     {'id': '296858', 'name': 'Android', 'results': 63},
#     {'id': '13310224', 'name': 'Google TV', 'results': 52},
#     {'id': '7601511', 'name': 'Android TV 6.0', 'results': 7},
#     {'id': '9777312', 'name': 'Android 10.0', 'results': 5},
#     {'id': '37746334', 'name': 'Android TV 11', 'results': 4},
#     {'id': '3026577', 'name': 'Android 7.1.2 Nougat', 'results': 3},
#     {'id': '9874057', 'name': 'Fire OS 6.2.7.7', 'results': 2},
#     {'id': '296859', 'name': 'iOS', 'results': 2},
#     {'id': '8958008', 'name': 'Android 5.0', 'results': 1},
#     {'id': '8828916', 'name': 'Android TV 9.0 Pie', 'results': 1},
#     {'id': '7818380', 'name': 'Android 9.0', 'results': 1},
#     {'id': '7606134', 'name': 'Fire OS 5', 'results': 1},
#     {'id': '43795032', 'name': 'Android TV 12', 'results': 1},
#     {'id': '38696982', 'name': 'Android', 'results': 1},
#     {'id': '38696979', 'name': 'Android', 'results': 1},
#     {'id': '355777', 'name': 'Linux', 'results': 1},
#     {'id': '3127891', 'name': 'Android 5.0 Lollipop', 'results': 1}]},
#   {'id': 'RAM_MEMORY',
#    'name': 'Memória RAM',
#    'type': 'range',
#    'values': [{'id': '(*-1.5GB)', 'name': 'Menos de 1,5 GB', 'results': 243},
#     {'id': '[1.5GB-8GB)', 'name': '1,5 a 7 GB', 'results': 341},
#     {'id': '[8GB-*)', 'name': '8 GB ou mais', 'results': 6}]},
#   {'id': 'REMOTE_CONTROL_TYPE',
#    'name': 'Tipo de controle remoto',
#    'type': 'STRING',
#    'values': [{'id': '17535337', 'name': 'De voz', 'results': 493},
#     {'id': '182134', 'name': 'Padrão', 'results': 60},
#     {'id': '43658304', 'name': 'Bluetooth', 'results': 2}]},
#   {'id': 'SHIPPING_ORIGIN',
#    'name': 'Tipo de compra',
#    'type': 'STRING',
#    'values': [{'id': '10215068', 'name': 'Local', 'results': 697},
#     {'id': '10215069', 'name': 'Internacional', 'results': 5}]},
#   {'id': 'WITH_BLUETOOTH',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Com Bluetooth', 'results': 602}]},
#   {'id': 'WITH_INTEGRATED_VOICE_ASSISTANTS',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com assistentes de voz integrados',
#      'results': 472}]},
#   {'id': 'WITH_WI_FI',
#    'name': 'Wi-Fi',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Com Wi-Fi', 'results': 682}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4', 'name': 'São Paulo', 'results': 498},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 62},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 36},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 20},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 16},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 14},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 12},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 9},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 8},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 7},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 5},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 2},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 1},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 1},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 1},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 1},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 1},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 1},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 1}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLB23436737', 'score': 1, 'status': 'shown'},
#    {'id': 'MLB33388968', 'score': 1, 'status': 'shown'},
#    {'id': 'MLB15984003', 'score': 1, 'status': 'shown'},
#    {'id': 'MLB13877783', 'score': 1, 'status': 'shown'},
#    {'id': 'MLB40923284', 'score': 1, 'status': 'shown'}]},
#  'user_context': None}

# %%
# Categories
url = "https://api.mercadolibre.com/sites/MLB/categories"
response = requests.get(url)
example_categories = response.json()

# %%
example_categories
# Out:
# [{'id': 'MLB5672', 'name': 'Acessórios para Veículos'},
#  {'id': 'MLB271599', 'name': 'Agro'},
#  {'id': 'MLB1403', 'name': 'Alimentos e Bebidas'},
#  {'id': 'MLB1071', 'name': 'Animais'},
#  {'id': 'MLB1367', 'name': 'Antiguidades e Coleções'},
#  {'id': 'MLB1368', 'name': 'Arte, Papelaria e Armarinho'},
#  {'id': 'MLB1384', 'name': 'Bebês'},
#  {'id': 'MLB1246', 'name': 'Beleza e Cuidado Pessoal'},
#  {'id': 'MLB1132', 'name': 'Brinquedos e Hobbies'},
#  {'id': 'MLB1430', 'name': 'Calçados, Roupas e Bolsas'},
#  {'id': 'MLB1039', 'name': 'Câmeras e Acessórios'},
#  {'id': 'MLB1743', 'name': 'Carros, Motos e Outros'},
#  {'id': 'MLB1574', 'name': 'Casa, Móveis e Decoração'},
#  {'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#  {'id': 'MLB1500', 'name': 'Construção'},
#  {'id': 'MLB5726', 'name': 'Eletrodomésticos'},
#  {'id': 'MLB1000', 'name': 'Eletrônicos, Áudio e Vídeo'},
#  {'id': 'MLB1276', 'name': 'Esportes e Fitness'},
#  {'id': 'MLB263532', 'name': 'Ferramentas'},
#  {'id': 'MLB12404', 'name': 'Festas e Lembrancinhas'},
#  {'id': 'MLB1144', 'name': 'Games'},
#  {'id': 'MLB1459', 'name': 'Imóveis'},
#  {'id': 'MLB1499', 'name': 'Indústria e Comércio'},
#  {'id': 'MLB1648', 'name': 'Informática'},
#  {'id': 'MLB218519', 'name': 'Ingressos'},
#  {'id': 'MLB1182', 'name': 'Instrumentos Musicais'},
#  {'id': 'MLB3937', 'name': 'Joias e Relógios'},
#  {'id': 'MLB1196', 'name': 'Livros, Revistas e Comics'},
#  {'id': 'MLB1168', 'name': 'Música, Filmes e Seriados'},
#  {'id': 'MLB264586', 'name': 'Saúde'},
#  {'id': 'MLB1540', 'name': 'Serviços'},
#  {'id': 'MLB1953', 'name': 'Mais Categorias'}]

# %%
# Advanced search Items by Category
category = "MLB1051"
url = f"https://api.mercadolibre.com/sites/MLB/search?category={category}"
response = requests.get(url)
item_examples = response.json()

# %%
len(item_examples['results'])
# Out:
# 50

# %%
item_examples['results'][0]
# Out:
# {'id': 'MLB4559453352',
#  'title': "Smartphone Motorola Moto G24 128gb 4gb 6,6'' Hd+ Android 14 4g/lite Dual Sim Grafite",
#  'condition': 'new',
#  'thumbnail_id': '919798-MLU74622536256_022024',
#  'catalog_product_id': 'MLB34079118',
#  'listing_type_id': 'gold_pro',
#  'sanitized_title': 'smartphone-motorola-moto-g24-128gb-4gb-66-hd-android-14-4glite-dual-sim-grafite',
#  'permalink': 'https://www.mercadolivre.com.br/smartphone-motorola-moto-g24-128gb-4gb-66-hd-android-14-4glite-dual-sim-grafite/p/MLB34079118#wid=MLB4559453352&sid=unknown',
#  'buying_mode': 'buy_it_now',
#  'site_id': 'MLB',
#  'category_id': 'MLB1055',
#  'domain_id': 'MLB-CELLPHONES',
#  'thumbnail': 'http://http2.mlstatic.com/D_919798-MLU74622536256_022024-I.jpg',
#  'currency_id': 'BRL',
#  'order_backend': 1,
#  'price': 725,
#  'original_price': 1240,
#  'sale_price': {'price_id': '',
#   'amount': 725,
#   'conditions': {'eligible': True,
#    'context_restrictions': ['channel_marketplace'],
#    'start_time': '2024-11-14T14:53:04Z',
#    'end_time': '2024-11-24T14:53:04Z'},
#   'currency_id': 'BRL',
#   'exchange_rate': None,
#   'payment_method_prices': [],
#   'payment_method_type': 'TMP',
#   'regular_amount': 1240,
#   'type': 'promotion',
#   'metadata': {'order_item_price': 725,
#    'promotion_id': 'OFFER-MLB4559453352-11072530760',
#    'promotion_type': 'marketplace_campaign',
#    'campaign_discount_percentage': 41.53,
#    'campaign_end_date': '2024-11-24T14:53:04Z',
#    'campaign_id': 'P-MLB14319108',
#    'discount_meli_amount': 43.5,
#    'funding_mode': 'sale_fee'}},
#  'available_quantity': 500,
#  'official_store_id': 3401,
#  'official_store_name': '123 Comprou',
#  'use_thumbnail_id': True,
#  'accepts_mercadopago': True,
#  'shipping': {'store_pick_up': False,
#   'free_shipping': True,
#   'logistic_type': 'fulfillment',
#   'mode': 'me2',
#   'tags': ['fulfillment',
#    'self_service_out',
#    'mandatory_free_shipping',
#    'self_service_available'],
#   'benefits': None,
#   'promise': None,
#   'shipping_score': -1},
#  'stop_time': '2044-10-13T12:30:51.987Z',
#  'seller': {'id': 85263796, 'nickname': '123 COMPROU'},
#  'address': {'state_id': 'BR-SP',
#   'state_name': 'São Paulo',
#   'city_id': 'BR-SP-41',
#   'city_name': 'Guarulhos'},
#  'attributes': [{'id': 'BRAND',
#    'name': 'Marca',
#    'value_id': '2503',
#    'value_name': 'Motorola',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '2503', 'name': 'Motorola', 'struct': None, 'source': 1}],
#    'source': 1,
#    'value_type': 'string'},
#   {'id': 'COLOR',
#    'name': 'Cor',
#    'value_id': '40829271',
#    'value_name': 'Grafite',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '40829271',
#      'name': 'Grafite',
#      'struct': None,
#      'source': 1}],
#    'source': 1,
#    'value_type': 'string'},
#   {'id': 'GPU_MODEL',
#    'name': 'Modelo de GPU',
#    'value_id': '36197810',
#    'value_name': 'ARM Mali-G52 MC2',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '36197810',
#      'name': 'ARM Mali-G52 MC2',
#      'struct': None,
#      'source': 4709228965570453}],
#    'source': 4709228965570453,
#    'value_type': 'string'},
#   {'id': 'GTIN',
#    'name': 'Código universal de produto',
#    'value_id': None,
#    'value_name': '7892597353811',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': None,
#      'name': '7892597353811',
#      'struct': None,
#      'source': 385122562515662}],
#    'source': 6402814585011704,
#    'value_type': 'string'},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição do item',
#    'value_id': '2230284',
#    'value_name': 'Novo',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '2230284',
#      'name': 'Novo',
#      'struct': None,
#      'source': 6402814585011704}],
#    'source': 6402814585011704,
#    'value_type': 'list'},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'value_id': '3073863',
#    'value_name': 'Moto G',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '3073863',
#      'name': 'Moto G',
#      'struct': None,
#      'source': 1}],
#    'source': 1,
#    'value_type': 'string'},
#   {'id': 'MAIN_COLOR',
#    'name': 'Cor principal',
#    'value_id': '2450294',
#    'value_name': 'Cinza',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '2450294', 'name': 'Cinza', 'struct': None, 'source': 1}],
#    'source': 1,
#    'value_type': 'list'},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'value_id': '8128788',
#    'value_name': 'G24',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '8128788', 'name': 'G24', 'struct': None, 'source': 1}],
#    'source': 1,
#    'value_type': 'string'},
#   {'id': 'PACKAGE_LENGTH',
#    'name': 'Comprimento da embalagem',
#    'value_id': None,
#    'value_name': '17.7 cm',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': {'number': 17.7, 'unit': 'cm'},
#    'values': [{'id': None,
#      'name': '17.7 cm',
#      'struct': {'unit': 'cm', 'number': 17.7},
#      'source': 4333789534002961}],
#    'source': 4333789534002961,
#    'value_type': 'number_unit'},
#   {'id': 'PACKAGE_WEIGHT',
#    'name': 'Peso da embalagem',
#    'value_id': None,
#    'value_name': '340 g',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': {'number': 340, 'unit': 'g'},
#    'values': [{'id': None,
#      'name': '340 g',
#      'struct': {'number': 340, 'unit': 'g'},
#      'source': 4333789534002961}],
#    'source': 4333789534002961,
#    'value_type': 'number_unit'},
#   {'id': 'PROCESSOR_MODEL',
#    'name': 'Modelo do processador',
#    'value_id': '8678039',
#    'value_name': 'MediaTek Helio G85',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': None,
#    'values': [{'id': '8678039',
#      'name': 'MediaTek Helio G85',
#      'struct': None,
#      'source': 1}],
#    'source': 1,
#    'value_type': 'string'},
#   {'id': 'WEIGHT',
#    'name': 'Peso',
#    'value_id': '462000',
#    'value_name': '181 g',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Outros',
#    'value_struct': {'number': 181, 'unit': 'g'},
#    'values': [{'id': '462000',
#      'name': '181 g',
#      'struct': {'number': 181, 'unit': 'g'},
#      'source': 4709228965570453}],
#    'source': 4709228965570453,
#    'value_type': 'number_unit'}],
#  'installments': {'quantity': 10,
#   'amount': 72.5,
#   'rate': 0,
#   'currency_id': 'BRL',
#   'metadata': {'meliplus_installments': False,
#    'additional_bank_interest': False}},
#  'winner_item_id': None,
#  'catalog_listing': True,
#  'discounts': None,
#  'decorations': None,
#  'promotions': [],
#  'inventory_id': 'ATFU36725'}

# %%
# Get Items
item_id = "MLB4559453352"
url = f"https://api.mercadolibre.com/items/{item_id}"
response = requests.get(url)
item_example = response.json()

# %%
item_example
# Out:
# {'id': 'MLB4559453352',
#  'site_id': 'MLB',
#  'title': "Smartphone Motorola Moto G24 128gb 4gb 6,6'' Hd+ Android 14 4g/lite Dual Sim Grafite",
#  'seller_id': 85263796,
#  'category_id': 'MLB1055',
#  'official_store_id': 3401,
#  'price': 1240,
#  'base_price': 1240,
#  'original_price': None,
#  'currency_id': 'BRL',
#  'initial_quantity': 18963,
#  'sale_terms': [{'id': 'WARRANTY_TYPE',
#    'name': 'Tipo de garantia',
#    'value_id': '2230279',
#    'value_name': 'Garantia de fábrica',
#    'value_struct': None,
#    'values': [{'id': '2230279',
#      'name': 'Garantia de fábrica',
#      'struct': None}],
#    'value_type': 'list'},
#   {'id': 'WARRANTY_TIME',
#    'name': 'Tempo de garantia',
#    'value_id': None,
#    'value_name': '12 meses',
#    'value_struct': {'number': 12, 'unit': 'meses'},
#    'values': [{'id': None,
#      'name': '12 meses',
#      'struct': {'number': 12, 'unit': 'meses'}}],
#    'value_type': 'number_unit'}],
#  'buying_mode': 'buy_it_now',
#  'listing_type_id': 'gold_pro',
#  'condition': 'new',
#  'permalink': 'https://produto.mercadolivre.com.br/MLB-4559453352-smartphone-motorola-moto-g24-128gb-4gb-66-hd-android-14-4glite-dual-sim-grafite-_JM',
#  'thumbnail_id': '919798-MLU74622536256_022024',
#  'thumbnail': 'http://http2.mlstatic.com/D_919798-MLU74622536256_022024-I.jpg',
#  'pictures': [{'id': '919798-MLU74622536256_022024',
#    'url': 'http://http2.mlstatic.com/D_919798-MLU74622536256_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_919798-MLU74622536256_022024-O.jpg',
#    'size': '390x500',
#    'max_size': '852x1090',
#    'quality': ''},
#   {'id': '713098-MLU74751306957_022024',
#    'url': 'http://http2.mlstatic.com/D_713098-MLU74751306957_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_713098-MLU74751306957_022024-O.jpg',
#    'size': '229x500',
#    'max_size': '418x909',
#    'quality': ''},
#   {'id': '865507-MLU74751475235_022024',
#    'url': 'http://http2.mlstatic.com/D_865507-MLU74751475235_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_865507-MLU74751475235_022024-O.jpg',
#    'size': '229x500',
#    'max_size': '419x912',
#    'quality': ''},
#   {'id': '643241-MLU74622585164_022024',
#    'url': 'http://http2.mlstatic.com/D_643241-MLU74622585164_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_643241-MLU74622585164_022024-O.jpg',
#    'size': '349x500',
#    'max_size': '650x931',
#    'quality': ''},
#   {'id': '811164-MLU74751306939_022024',
#    'url': 'http://http2.mlstatic.com/D_811164-MLU74751306939_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_811164-MLU74751306939_022024-O.jpg',
#    'size': '426x500',
#    'max_size': '800x937',
#    'quality': ''},
#   {'id': '962634-MLU74622181544_022024',
#    'url': 'http://http2.mlstatic.com/D_962634-MLU74622181544_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_962634-MLU74622181544_022024-O.jpg',
#    'size': '471x500',
#    'max_size': '919x975',
#    'quality': ''},
#   {'id': '866641-MLU74622181558_022024',
#    'url': 'http://http2.mlstatic.com/D_866641-MLU74622181558_022024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_866641-MLU74622181558_022024-O.jpg',
#    'size': '457x500',
#    'max_size': '792x866',
#    'quality': ''}],
#  'video_id': None,
#  'descriptions': [],
#  'accepts_mercadopago': True,
#  'non_mercado_pago_payment_methods': [],
#  'shipping': {'mode': 'me2',
#   'methods': [],
#   'tags': ['self_service_out',
#    'mandatory_free_shipping',
#    'self_service_available'],
#   'dimensions': None,
#   'local_pick_up': False,
#   'free_shipping': True,
#   'logistic_type': 'fulfillment',
#   'store_pick_up': False},
#  'international_delivery_mode': 'none',
#  'seller_address': {'city': {'id': 'BR-SP-41', 'name': 'Guarulhos'},
#   'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#   'country': {'id': 'BR', 'name': 'Brasil'},
#   'search_location': {'neighborhood': {'id': 'TUxCQlJFU2Qydjhi',
#     'name': 'Residencial Parque Cumbica'},
#    'city': {'id': 'TUxCQ1NQLTcyOTU', 'name': 'Guarulhos'},
#    'state': {'id': 'TUxCUFNBT085N2E4', 'name': 'São Paulo'}},
#   'id': 1055030833},
#  'seller_contact': None,
#  'location': {},
#  'coverage_areas': [],
#  'attributes': [{'id': 'ADDITIONAL_INFO_REQUIRED',
#    'name': 'Informação adicional requerida',
#    'value_id': None,
#    'value_name': 'Possui código IMEI,Possui número de série',
#    'values': [{'id': '7435893', 'name': 'Possui código IMEI', 'struct': None},
#     {'id': '7435894', 'name': 'Possui número de série', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'ALPHANUMERIC_MODELS',
#    'name': 'Modelo alfanumérico',
#    'value_id': '41652524',
#    'value_name': 'XT242-6',
#    'values': [{'id': '41652524', 'name': 'XT242-6', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'ANATEL_HOMOLOGATION_NUMBER',
#    'name': 'Homologação Anatel Nº',
#    'value_id': None,
#    'value_name': '206672300330',
#    'values': [{'id': None, 'name': '206672300330', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'BATTERY_CAPACITY',
#    'name': 'Capacidade da bateria',
#    'value_id': '98439',
#    'value_name': '5000 mAh',
#    'values': [{'id': '98439',
#      'name': '5000 mAh',
#      'struct': {'number': 5000, 'unit': 'mAh'}}],
#    'value_type': 'number_unit'},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'value_id': '2503',
#    'value_name': 'Motorola',
#    'values': [{'id': '2503', 'name': 'Motorola', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'value_id': '298335',
#    'value_name': 'Desbloqueado',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'CELLPHONES_ANATEL_HOMOLOGATION_NUMBER',
#    'name': 'Número de homologação da Anatel',
#    'value_id': '38969028',
#    'value_name': '206672300330',
#    'values': [{'id': '38969028', 'name': '206672300330', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'CHARGE_CONNECTOR_TYPE',
#    'name': 'Tipo de conector de carregamento',
#    'value_id': '8275367',
#    'value_name': 'USB-C',
#    'values': [{'id': '8275367', 'name': 'USB-C', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'COLOR',
#    'name': 'Cor',
#    'value_id': '40829271',
#    'value_name': 'Grafite',
#    'values': [{'id': '40829271', 'name': 'Grafite', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'COMPATIBLE_SIM_CARD_SIZES',
#    'name': 'Tamanhos de cartão SIM compatíveis',
#    'value_id': '34891752',
#    'value_name': 'Nano SIM',
#    'values': [{'id': '34891752', 'name': 'Nano SIM', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'DEPTH',
#    'name': 'Profundidade',
#    'value_id': '38917716',
#    'value_name': '8.03 mm',
#    'values': [{'id': '38917716',
#      'name': '8.03 mm',
#      'struct': {'number': 8.03, 'unit': 'mm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'DIGITAL_ZOOM',
#    'name': 'Zoom digital',
#    'value_id': '7206950',
#    'value_name': '4x',
#    'values': [{'id': '7206950',
#      'name': '4x',
#      'struct': {'number': 4, 'unit': 'x'}}],
#    'value_type': 'number_unit'},
#   {'id': 'DISPLAY_ASPECT_RATIO',
#    'name': 'Proporção da tela',
#    'value_id': '11328153',
#    'value_name': '20:9',
#    'values': [{'id': '11328153', 'name': '20:9', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'DISPLAY_PIXELS_PER_INCH',
#    'name': 'Pixels por polegada da tela',
#    'value_id': '7073988',
#    'value_name': '269 ppi',
#    'values': [{'id': '7073988',
#      'name': '269 ppi',
#      'struct': {'number': 269, 'unit': 'ppi'}}],
#    'value_type': 'number_unit'},
#   {'id': 'DISPLAY_REFRESH_RATE',
#    'name': 'Taxa de atualização da tela',
#    'value_id': '9569230',
#    'value_name': '90 Hz',
#    'values': [{'id': '9569230',
#      'name': '90 Hz',
#      'struct': {'number': 90, 'unit': 'Hz'}}],
#    'value_type': 'number_unit'},
#   {'id': 'DISPLAY_RESOLUTION',
#    'name': 'Resolução da tela',
#    'value_id': '8039796',
#    'value_name': '720 px x 1600 px',
#    'values': [{'id': '8039796', 'name': '720 px x 1600 px', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'DISPLAY_RESOLUTION_TYPE',
#    'name': 'Tipo de resolução da tela',
#    'value_id': '9571056',
#    'value_name': 'HD+',
#    'values': [{'id': '9571056', 'name': 'HD+', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'DISPLAY_SIZE',
#    'name': 'Tamanho da tela',
#    'value_id': '8767166',
#    'value_name': '6.6 "',
#    'values': [{'id': '8767166',
#      'name': '6.6 "',
#      'struct': {'number': 6.6, 'unit': '"'}}],
#    'value_type': 'number_unit'},
#   {'id': 'DISPLAY_TECHNOLOGY',
#    'name': 'Tecnologia da tela',
#    'value_id': '80490',
#    'value_name': 'IPS',
#    'values': [{'id': '80490', 'name': 'IPS', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'FRONT_CAMERAS_NUMBER',
#    'name': 'Quantidade de câmeras frontais',
#    'value_id': '7477216',
#    'value_name': '1',
#    'values': [{'id': '7477216', 'name': '1', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'FRONT_CAMERAS_RESOLUTION',
#    'name': 'Resolução das câmeras frontais',
#    'value_id': '8476375',
#    'value_name': '8 Mpx',
#    'values': [{'id': '8476375', 'name': '8 Mpx', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'FRONT_CAMERAS_TYPES',
#    'name': 'Tipos de câmeras frontais',
#    'value_id': '8275359',
#    'value_name': 'Regular',
#    'values': [{'id': '8275359', 'name': 'Regular', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'FRONT_CAMERA_APERTURE',
#    'name': 'Abertura do diafragma da câmera frontal',
#    'value_id': '7408577',
#    'value_name': 'f 2.0',
#    'values': [{'id': '7408577', 'name': 'f 2.0', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'FRONT_CAMERA_RECORDING_RESOLUTION',
#    'name': 'Resolução de vídeo da câmera frontal',
#    'value_id': '7173215',
#    'value_name': '1920 px x 1080 px',
#    'values': [{'id': '7173215', 'name': '1920 px x 1080 px', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'GPU_MODEL',
#    'name': 'Modelo de GPU',
#    'value_id': '36197810',
#    'value_name': 'ARM Mali-G52 MC2',
#    'values': [{'id': '36197810', 'name': 'ARM Mali-G52 MC2', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'GTIN',
#    'name': 'Código universal de produto',
#    'value_id': None,
#    'value_name': '7892597353811',
#    'values': [{'id': None, 'name': '7892597353811', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'HAZMAT_TRANSPORTABILITY',
#    'name': 'Transportabilidade Hazmat',
#    'value_id': '13414677',
#    'value_name': 'Livre',
#    'values': [{'id': '13414677', 'name': 'Livre', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'HEIGHT',
#    'name': 'Altura',
#    'value_id': '35575436',
#    'value_name': '163.49 mm',
#    'values': [{'id': '35575436',
#      'name': '163.49 mm',
#      'struct': {'number': 163.49, 'unit': 'mm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'value_id': '84611',
#    'value_name': '128 GB',
#    'values': [{'id': '84611',
#      'name': '128 GB',
#      'struct': {'number': 128, 'unit': 'GB'}}],
#    'value_type': 'number_unit'},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'É Dual SIM',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'IS_GAMING_CELLPHONE',
#    'name': 'É celular para jogos',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'IS_KIT',
#    'name': 'É kit',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'IS_RUGGED_CELLPHONE',
#    'name': 'É celular robusto',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição do item',
#    'value_id': '2230284',
#    'value_name': 'Novo',
#    'values': [{'id': '2230284', 'name': 'Novo', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'value_id': '3073863',
#    'value_name': 'Moto G',
#    'values': [{'id': '3073863', 'name': 'Moto G', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MAIN_COLOR',
#    'name': 'Cor principal',
#    'value_id': '2450294',
#    'value_name': 'Cinza',
#    'values': [{'id': '2450294', 'name': 'Cinza', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'MAIN_FRONT_CAMERA_RESOLUTION',
#    'name': 'Resolução da câmera frontal principal',
#    'value_id': '7207052',
#    'value_name': '8 Mpx',
#    'values': [{'id': '7207052',
#      'name': '8 Mpx',
#      'struct': {'number': 8, 'unit': 'Mpx'}}],
#    'value_type': 'number_unit'},
#   {'id': 'MAIN_REAR_CAMERA_RESOLUTION',
#    'name': 'Resolução da câmera traseira principal',
#    'value_id': '8232281',
#    'value_name': '50 Mpx',
#    'values': [{'id': '8232281',
#      'name': '50 Mpx',
#      'struct': {'number': 50, 'unit': 'Mpx'}}],
#    'value_type': 'number_unit'},
#   {'id': 'MANUFACTURER',
#    'name': 'Fabricante',
#    'value_id': '2503',
#    'value_name': 'Motorola',
#    'values': [{'id': '2503', 'name': 'Motorola', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MAX_DISPLAY_BRIGHTNESS',
#    'name': 'Brilho máximo da tela',
#    'value_id': '1160581',
#    'value_name': '500 cd/m²',
#    'values': [{'id': '1160581',
#      'name': '500 cd/m²',
#      'struct': {'number': 500, 'unit': 'cd/m²'}}],
#    'value_type': 'number_unit'},
#   {'id': 'MEMORY_CARD_MAX_CAPACITY',
#    'name': 'Capacidade máxima do cartão de memória',
#    'value_id': '7408581',
#    'value_name': '1 TB',
#    'values': [{'id': '7408581',
#      'name': '1 TB',
#      'struct': {'number': 1, 'unit': 'TB'}}],
#    'value_type': 'number_unit'},
#   {'id': 'MEMORY_CARD_TYPES',
#    'name': 'Tipos de cartão de memória',
#    'value_id': '7199655',
#    'value_name': 'Micro-SD',
#    'values': [{'id': '7199655', 'name': 'Micro-SD', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MOBILE_NETWORK',
#    'name': 'Rede móvel',
#    'value_id': '367876',
#    'value_name': '4G/LTE',
#    'values': [{'id': '367876', 'name': '4G/LTE', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'value_id': '8128788',
#    'value_name': 'G24',
#    'values': [{'id': '8128788', 'name': 'G24', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'OPERATING_SYSTEM_EDITION',
#    'name': 'Edição do sistema operacional',
#    'value_id': '28105730',
#    'value_name': 'Android 14',
#    'values': [{'id': '28105730', 'name': 'Android 14', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'OPERATING_SYSTEM_NAME',
#    'name': 'Nome do sistema operacional',
#    'value_id': '7403813',
#    'value_name': 'Android',
#    'values': [{'id': '7403813', 'name': 'Android', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'OS_LAST_COMPATIBLE_VERSION',
#    'name': 'Última versão compatível do sistema operacional',
#    'value_id': '19988452',
#    'value_name': '14',
#    'values': [{'id': '19988452', 'name': '14', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'OS_ORIGINAL_VERSION',
#    'name': 'Versão original do sistema operacional',
#    'value_id': '9094175',
#    'value_name': '14',
#    'values': [{'id': '9094175', 'name': '14', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'PACKAGE_HEIGHT',
#    'name': 'Altura da embalagem',
#    'value_id': None,
#    'value_name': '4.9 cm',
#    'values': [{'id': None,
#      'name': '4.9 cm',
#      'struct': {'number': 4.9, 'unit': 'cm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'PACKAGE_LENGTH',
#    'name': 'Comprimento da embalagem',
#    'value_id': None,
#    'value_name': '17.7 cm',
#    'values': [{'id': None,
#      'name': '17.7 cm',
#      'struct': {'number': 17.7, 'unit': 'cm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'PACKAGE_WEIGHT',
#    'name': 'Peso da embalagem',
#    'value_id': None,
#    'value_name': '340 g',
#    'values': [{'id': None,
#      'name': '340 g',
#      'struct': {'number': 340, 'unit': 'g'}}],
#    'value_type': 'number_unit'},
#   {'id': 'PACKAGE_WIDTH',
#    'name': 'Largura da embalagem',
#    'value_id': None,
#    'value_name': '9.8 cm',
#    'values': [{'id': None,
#      'name': '9.8 cm',
#      'struct': {'number': 9.8, 'unit': 'cm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'PROCESSOR_CORES_NUMBER',
#    'name': 'Quantidade de núcleos do processador',
#    'value_id': '7206961',
#    'value_name': '8',
#    'values': [{'id': '7206961', 'name': '8', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'PROCESSOR_MODEL',
#    'name': 'Modelo do processador',
#    'value_id': '8678039',
#    'value_name': 'MediaTek Helio G85',
#    'values': [{'id': '8678039', 'name': 'MediaTek Helio G85', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'PROCESSOR_SPEED',
#    'name': 'Velocidade do processador',
#    'value_id': '365995',
#    'value_name': '2 GHz',
#    'values': [{'id': '365995',
#      'name': '2 GHz',
#      'struct': {'number': 2, 'unit': 'GHz'}}],
#    'value_type': 'number_unit'},
#   {'id': 'PRODUCT_FEATURES',
#    'name': 'Características do produto',
#    'value_id': None,
#    'value_name': 'Frágil,Sem validade',
#    'values': [{'id': '7435883', 'name': 'Frágil', 'struct': None},
#     {'id': '8847339', 'name': 'Sem validade', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'RAM',
#    'name': 'Memória RAM',
#    'value_id': '98852',
#    'value_name': '4 GB',
#    'values': [{'id': '98852',
#      'name': '4 GB',
#      'struct': {'number': 4, 'unit': 'GB'}}],
#    'value_type': 'number_unit'},
#   {'id': 'REAR_CAMERAS_NUMBER',
#    'name': 'Quantidade de câmeras traseiras',
#    'value_id': '7477262',
#    'value_name': '2',
#    'values': [{'id': '7477262', 'name': '2', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'REAR_CAMERAS_RESOLUTION',
#    'name': 'Resolução das câmeras traseiras',
#    'value_id': '11934659',
#    'value_name': '50 Mpx/2 Mpx',
#    'values': [{'id': '11934659', 'name': '50 Mpx/2 Mpx', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'REAR_CAMERA_APERTURE',
#    'name': 'Abertura do diafragma da câmera traseira',
#    'value_id': '7505957',
#    'value_name': 'f 1.8/f 2.4',
#    'values': [{'id': '7505957', 'name': 'f 1.8/f 2.4', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'REAR_CAMERA_RECORDING_RESOLUTION',
#    'name': 'Resolução de vídeo da câmera traseira',
#    'value_id': '36197807',
#    'value_name': '1920 px x 864 px',
#    'values': [{'id': '36197807', 'name': '1920 px x 864 px', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'RELEASE_MONTH',
#    'name': 'Mês de lançamento',
#    'value_id': '8275340',
#    'value_name': 'Janeiro',
#    'values': [{'id': '8275340', 'name': 'Janeiro', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'RELEASE_YEAR',
#    'name': 'Ano de lançamento',
#    'value_id': '22764580',
#    'value_name': '2024',
#    'values': [{'id': '22764580', 'name': '2024', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'SECONDARY_DISPLAY_REFRESH_RATE',
#    'name': 'Taxa de atualização da tela secundária',
#    'value_id': '9952768',
#    'value_name': '90 Hz',
#    'values': [{'id': '9952768',
#      'name': '90 Hz',
#      'struct': {'number': 90, 'unit': 'Hz'}}],
#    'value_type': 'number_unit'},
#   {'id': 'SELLER_SKU',
#    'name': 'SKU',
#    'value_id': None,
#    'value_name': 'C-342',
#    'values': [{'id': None, 'name': 'C-342', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'SHIPMENT_PACKING',
#    'name': 'Embalagem do envío',
#    'value_id': '7435891',
#    'value_name': 'Flyer',
#    'values': [{'id': '7435891', 'name': 'Flyer', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'SIM_CARD_SLOTS_NUMBER',
#    'name': 'Quantidade de ranhuras para cartão SIM',
#    'value_id': '2087802',
#    'value_name': '2',
#    'values': [{'id': '2087802', 'name': '2', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'WEIGHT',
#    'name': 'Peso',
#    'value_id': '462000',
#    'value_name': '181 g',
#    'values': [{'id': '462000',
#      'name': '181 g',
#      'struct': {'number': 181, 'unit': 'g'}}],
#    'value_type': 'number_unit'},
#   {'id': 'WIDTH',
#    'name': 'Largura',
#    'value_id': '34333269',
#    'value_name': '74.53 mm',
#    'values': [{'id': '34333269',
#      'name': '74.53 mm',
#      'struct': {'number': 74.53, 'unit': 'mm'}}],
#    'value_type': 'number_unit'},
#   {'id': 'WITH_ACCELEROMETER',
#    'name': 'Com acelerômetro',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_BLUETOOTH',
#    'name': 'Com Bluetooth',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_CAMERA',
#    'name': 'Com câmera',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_COMPASS',
#    'name': 'Com bússola',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_ESIM',
#    'name': 'Com eSIM',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Com reconhecimento facial',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_FAST_CHARGING',
#    'name': 'Com carregamento rápido',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Com leitor de impressão digital',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_FRONT_CAMERA_FLASH',
#    'name': 'Com flash na câmara frontal',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_GPS',
#    'name': 'Com GPS',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_GYROSCOPE',
#    'name': 'Com giroscópio',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_IMEI',
#    'name': 'Com IMEI',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_MEMORY_CARD_SLOT',
#    'name': 'Com ranhura para cartão de memória',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_NFC',
#    'name': 'Com NFC',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_PROXIMITY_SENSOR',
#    'name': 'Com sensor de proximidade',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_RADIO',
#    'name': 'Com radio',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_REMOVABLE_BATTERY',
#    'name': 'Com bateria removível',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_TOUCHSCREEN_DISPLAY',
#    'name': 'Com tela tátil',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_TV_TUNER',
#    'name': 'Com sintonizador de TV',
#    'value_id': '242084',
#    'value_name': 'Não',
#    'values': [{'id': '242084', 'name': 'Não', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_USB_CONNECTOR',
#    'name': 'Com conector USB',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'WITH_WIFI',
#    'name': 'Com Wi-Fi',
#    'value_id': '242085',
#    'value_name': 'Sim',
#    'values': [{'id': '242085', 'name': 'Sim', 'struct': None}],
#    'value_type': 'boolean'}],
#  'listing_source': '',
#  'variations': [],
#  'status': 'active',
#  'sub_status': [],
#  'tags': ['extended_warranty_eligible',
#   'good_quality_thumbnail',
#   'standard_price_by_channel',
#   'mshops_3x_campaign',
#   'immediate_payment',
#   'cart_eligible'],
#  'warranty': 'Garantia de fábrica: 12 meses',
#  'catalog_product_id': 'MLB34079118',
#  'domain_id': 'MLB-CELLPHONES',
#  'parent_item_id': None,
#  'deal_ids': ['MLB23573'],
#  'automatic_relist': False,
#  'date_created': '2024-03-27T18:21:29.000Z',
#  'last_updated': '2024-11-23T02:34:12.186Z',
#  'health': None,
#  'catalog_listing': True}

# %% [markdown]
# Decidi usar a pesquisa de itens por categoria. E como os dados que eu gostaria de analisar já estão no retorno do search, decidi não fazer uma nova chamada get em items.

# %% [markdown]
# ## Task 2

# %%
def get_categories():
    url = "https://api.mercadolibre.com/sites/MLB/categories"
    response = requests.get(url)
    categories = response.json()
    return categories

# %%
def search_items_by_category(category_id:str):
    url = f"https://api.mercadolibre.com/sites/MLB/search?category={category_id}"
    response = requests.get(url)
    items = response.json()['results']
    return items

# %%
all_categories = get_categories()[10:20]
all_categories
# Out:
# [{'id': 'MLB1039', 'name': 'Câmeras e Acessórios'},
#  {'id': 'MLB1743', 'name': 'Carros, Motos e Outros'},
#  {'id': 'MLB1574', 'name': 'Casa, Móveis e Decoração'},
#  {'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#  {'id': 'MLB1500', 'name': 'Construção'},
#  {'id': 'MLB5726', 'name': 'Eletrodomésticos'},
#  {'id': 'MLB1000', 'name': 'Eletrônicos, Áudio e Vídeo'},
#  {'id': 'MLB1276', 'name': 'Esportes e Fitness'},
#  {'id': 'MLB263532', 'name': 'Ferramentas'},
#  {'id': 'MLB12404', 'name': 'Festas e Lembrancinhas'}]

# %%
all_items_metadata = []
for category in all_categories:
    items = search_items_by_category(category['id'])
    for item in items:
        # Baseado nos dados retornados, escolhi os seguintes para análise
        metadata = {
            "id": item['id'],
            "title": item['title'],
            "condition": item['condition'],
            "category_id": item['category_id'],
            "category_name": category['name'],
            "seller_id": item['seller']['id'],
            "seller_nickname": item['seller']['nickname'],
            "original_price": item['original_price'],
            "sale_price": item['sale_price']['amount'],
            "available_quantity": item['available_quantity'],
            "store_pick_up": item['shipping']['store_pick_up'],
            "free_shipping": item['shipping']['free_shipping'],
            "state_name": item['address']['state_name'],
            "city_name": item['address']['city_name'],
        }
        all_items_metadata.append(metadata)

# %%
all_items_metadata[:5]
# Out:
# [{'id': 'MLB3655023677',
#   'title': 'Suporte Fundo Infinito+ Bolsa+ 16 Presilhas Fotográfica Pro',
#   'condition': 'new',
#   'category_id': 'MLB271836',
#   'category_name': 'Câmeras e Acessórios',
#   'seller_id': 808787852,
#   'seller_nickname': 'USEFULCOMERCIALLTDA',
#   'original_price': 197,
#   'sale_price': 159.57,
#   'available_quantity': 150,
#   'store_pick_up': False,
#   'free_shipping': True,
#   'state_name': 'São Paulo',
#   'city_name': 'Cravinhos'},
#  {'id': 'MLB4587481424',
#   'title': 'Câmera Descartável Kodak Funsaver Preta/vermelha/amarela',
#   'condition': 'new',
#   'category_id': 'MLB1985',
#   'category_name': 'Câmeras e Acessórios',
#   'seller_id': 833768103,
#   'seller_nickname': 'BEMSONJDCOMERCIALLTDABEMSO',
#   'original_price': None,
#   'sale_price': 199,
#   'available_quantity': 1,
#   'store_pick_up': False,
#   'free_shipping': True,
#   'state_name': 'São Paulo',
#   'city_name': 'São Paulo'},
#  {'id': 'MLB4092885690',
#   'title': 'Porta Banner C/ Garras 1,80 Suporte Pedestal Imediato',
#   'condition': 'new',
#   'category_id': 'MLB103465',
#   'category_name': 'Câmeras e Acessórios',
#   'seller_id': 152024409,
#   'seller_nickname': 'CEPROPLASTBRINDES',
#   'original_price': 72.9,
#   'sale_price': 46.65,
#   'available_quantity': 250,
#   'store_pick_up': False,
#   'free_shipping': False,
#   'state_name': 'São Paulo',
#   'city_name': 'Cravinhos'},
#  {'id': 'MLB4296907580',
#   'title': 'Binóculo Diurno E Noturno Zoom 30x60 Até 1000m Profissional',
#   'condition': 'new',
#   'category_id': 'MLB4063',
#   'category_name': 'Câmeras e Acessórios',
#   'seller_id': 1282834350,
#   'seller_nickname': 'ONLY.L',
#   'original_price': 42.9,
#   'sale_price': 35.17,
#   'available_quantity': 500,
#   'store_pick_up': False,
#   'free_shipping': False,
#   'state_name': 'São Paulo',
#   'city_name': 'São Paulo'},
#  {'id': 'MLB5066959072',
#   'title': 'Lâmpada Tricool Para Softbox 135w 5500k T-photo 110v',
#   'condition': 'new',
#   'category_id': 'MLB38267',
#   'category_name': 'Câmeras e Acessórios',
#   'seller_id': 175729038,
#   'seller_nickname': '4FITNESS',
#   'original_price': 56.99,
#   'sale_price': 49.58,
#   'available_quantity': 100,
#   'store_pick_up': False,
#   'free_shipping': False,
#   'state_name': 'Paraná',
#   'city_name': 'Curitiba'}]

# %%
len(all_items_metadata)
# Out:
# 499

# %% [markdown]
# ## Task 3

# %%
import csv

keys = all_items_metadata[0].keys()

with open('all_items_metadata.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_items_metadata)
